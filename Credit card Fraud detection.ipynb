# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
df=pd.read_csv("C:/Users/Nitish/Desktop/creditcard.csv.zip")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# ## Data analysis and Visualization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.groupby("Class").count() # showing the count of 0 and 1.
# Out:
#          Time      V1      V2      V3      V4      V5      V6      V7      V8  \
# Class
# 0      284315  284315  284315  284315  284315  284315  284315  284315  284315
# 1         492     492     492     492     492     492     492     492     492
#
#            V9  ...     V20     V21     V22     V23     V24     V25     V26  \
# Class          ...
# 0      284315  ...  284315  284315  284315  284315  284315  284315  284315
# 1         492  ...     492     492     492     492     492     492     492
#
#           V27     V28  Amount
# Class
# 0      284315  284315  284315
# 1         492     492     492
#
# [2 rows x 30 columns]

# %%
df.groupby("Class")["Time"].agg([np.mean,np.median,min,max]) # avg amount of time elapsed between transactions are less for the fraudalent transactions
# Out:
#                mean   median    min       max
# Class
# 0      94838.202258  84711.0    0.0  172792.0
# 1      80746.806911  75568.5  406.0  170348.0

# %%
df.groupby("Class")["Amount"].agg([np.mean,np.median,min,max])# Avg. transaction amount is more in case of a fraud.
# Out:
#              mean  median  min       max
# Class
# 0       88.291022   22.00  0.0  25691.16
# 1      122.211321    9.25  0.0   2125.87

# %%
sns.set(style="darkgrid")
sns.countplot(x="Class",data=df) # it can be seen that large amount of data contains class 0 (No fraud). data is highly imbalanced

# %%
sns.barplot(x="Class",y="Amount",data=df)# this shows that fraudulent transactions amount on an avg is higher than the  normal transactions.

# %%
sns.barplot(x="Class",y="Amount",data=df) # visual represenation:: Self explanatory. Explained it before also.

# %%
sns.relplot(x="Time",y="Amount",hue="Class",data=df) #scatter plot.

# %%
#Using Pearson Correlation
plt.figure(figsize=(40,40))
cor = df.corr()
mask = np.zeros(cor.shape, dtype=bool)
mask[np.triu_indices(len(mask))] = True
sns.heatmap(cor, annot=True,
            cmap='coolwarm',mask=mask,vmin = -1, vmax = 1, center = 0)


plt.show() # it can be seen that our feature variables are not much correlated. Its is close to 0 for our main variables, TIME AND AMOOUNT AND CLASS.

# %%
y=df.Class
X=df.drop("Class",axis=1)
print(y)
print(X)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# ...

# %% [markdown]
# ## Dealing with imbalanced data

# %%
from imblearn.combine import SMOTETomek
smk=SMOTETomek(random_state=42)
X_res,y_res=smk.fit_sample(X,y) # implementing over sampling to handle imbalanced dataset.
print(X_res.shape)
print(y_res.shape)
# Out:
# (567562, 30)
# (567562,)

# %%
y_res
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 567557    1
# 567558    1
# 567559    1
# 567560    1
# 567561    1
# Name: Class, Length: 567562, dtype: int64

# %%
X_res
# Out:
#                  Time        V1        V2        V3        V4        V5  \
# 0            0.000000 -1.359807 -0.072781  2.536347  1.378155 -0.338321
# 1            0.000000  1.191857  0.266151  0.166480  0.448154  0.060018
# 2            1.000000 -1.358354 -1.340163  1.773209  0.379780 -0.503198
# 3            1.000000 -0.966272 -0.185226  1.792993 -0.863291 -0.010309
# 4            2.000000 -1.158233  0.877737  1.548718  0.403034 -0.407193
# ...               ...       ...       ...       ...       ...       ...
# 567557  144838.659385 -6.379157  1.672637 -5.885670  2.068340 -0.668576
# 567558   65965.011763 -2.479028  0.958932 -1.782249  1.541783 -1.191990
# 567559   34592.129093 -1.799894  2.368957 -2.673997  1.705968 -1.355923
# 567560  129683.002907  0.255234  2.432041 -5.388252  3.793925 -0.230814
# 567561   91471.277869 -4.453646  3.210469 -5.294410  1.449911 -1.264653
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
from collections import Counter
print("Original_data_shape is {}".format(Counter(y)))
print("new_data_Shape is {}".format(Counter(y_res))) # now we can see equal no. of 0's and 1's
# Out:
# Original_data_shape is Counter({0: 284315, 1: 492})
# new_data_Shape is Counter({0: 283781, 1: 283781})

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_res,y_res,test_size=0.3,stratify=y_res)

# %%
print(X_train.shape)
print(y_train.shape)      
print(X_test.shape)
print(y_test.shape)
# Out:
# (397293, 30)
# (397293,)
# (170269, 30)
# (170269,)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,y_train)
predictions=model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,predictions)
# Out:
# array([[83359,  1775],
#        [ 3022, 82113]], dtype=int64)

# %%
model.predict_proba(X_test)
# Out:
# array([[8.65964985e-06, 9.99991340e-01],
#        [9.67880854e-01, 3.21191463e-02],
#        [9.43339459e-01, 5.66605411e-02],
#        ...,
#        [9.97947037e-01, 2.05296304e-03],
#        [9.11049014e-13, 1.00000000e+00],
#        [9.99387188e-01, 6.12811638e-04]])

# %%
model.predict_proba(X_test)[: ,1] # to get relevant probabilities needed for ROC AND AUC.
# Out:
# array([9.99991340e-01, 3.21191463e-02, 5.66605411e-02, ...,
#        2.05296304e-03, 1.00000000e+00, 6.12811638e-04])

# %%
from sklearn.metrics import recall_score
recall_score(y_test,predictions)
# Out:
# 0.9645034357197393

# %%
from sklearn.metrics import roc_curve,roc_auc_score
fpr,tpr,thresholds= roc_curve(y_test,model.predict_proba(X_test)[: ,1])

# %%
thresholds
# Out:
# array([2.00000000e+00, 1.00000000e+00, 1.00000000e+00, ...,
#        6.99488660e-05, 6.98645448e-05, 4.71402622e-07])

# %% [markdown]
# ## Plotting ROC CURVE AND GETTING AUC SCORE

# %%
plt.plot(fpr,tpr,color="red")
plt.xlabel("False postive rate")
plt.ylabel("True positive rate")
plt.title("ROC CURVE")
# Out:
# Text(0.5, 1.0, 'ROC CURVE')

# %%
roc_auc_score(y_test,model.predict_proba(X_test)[: ,1]) # shows that this logistic model performed well
# Out:
# 0.993214058451376
